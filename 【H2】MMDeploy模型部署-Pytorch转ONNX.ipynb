# %% [markdown]
# # MMDeploy模型部署-Pytorch转ONNX

# %% [markdown]
# ### deploy 参数
# ```
# python ./tools/deploy.py \
#     ${DEPLOY_CFG_PATH} \
#     ${MODEL_CFG_PATH} \
#     ${MODEL_CHECKPOINT_PATH} \
#     ${INPUT_IMG} \
#     --test-img ${TEST_IMG} \
#     --work-dir ${WORK_DIR} \
#     --calib-dataset-cfg ${CALIB_DATA_CFG} \
#     --device ${DEVICE} \
#     --log-level INFO \
#     --show \
#     --dump-info
#
# ```
#
# [参考](https://blog.csdn.net/qq_40622955/article/details/138123226)

# %%
# !python mmdeploy/tools/deploy.py \
#     mmdeploy/configs/mmpose/pose-detection_onnxruntime_static.py \
#     mmpose/configs/body_2d_keypoint/topdown_heatmap/coco/td-hm_hrnet-w32_8xb64-210e_coco-256x192.py \
#     mmpose/checkpoint/body_2d_keypoint/td-hm_hrnet-w32_8xb64-210e_coco-256x192-81c58e40_20220909.pth \
#     'data/human-pose.jpg' \
#     --work-dir mmdeploy/mmdeploy_models/mmpose/ort \
#     --device cuda \
#     --show


# !python mmdeploy/tools/deploy.py \
#     mmdeploy/configs/mmpose/pose-detection_simcc_onnxruntime_dynamic.py \
#     mmpose/work_dirs/rtmpose-t_8xb256-420e_coco-256x192/rtmpose-t_8xb256-420e_coco-256x192.py \
#     mmpose/checkpoint/rtmpose-t_8xb256-420e_coco-256x192-100-97c86b4e_20241204.pth \
#     'data/multi-person.jpg' \
#     --work-dir mmdeploy/mmdeploy_models/mmpose/ort_test \
#     --device cuda \
#     --show 

    
# !python mmdeploy/tools/deploy.py \
    mmdeploy/configs/mmpose/pose-detection_simcc_onnxruntime_dynamic.py \
    mmpose/configs/body_2d_keypoint/rtmpose/coco/rtmpose-t_8xb256-420e_coco-256x192.py \
    mmpose/checkpoint/rtmpose-t_8xb256-420e_coco-256x192-100-97c86b4e_20241204.pth \
    'data/human-pose.jpg' \
    --work-dir mmdeploy/mmdeploy_models/mmpose/ort_test_ding \
    --device cuda \
    --show \
    --dump-info \
    --quant
# !python mmdeploy/tools/deploy.py \
#     mmdeploy/configs/mmpose/pose-detection_simcc_ncnn-fp16_static-256x192.py \
#     mmpose/work_dirs/rtmpose-t_8xb256-420e_coco-256x192/rtmpose-t_8xb256-420e_coco-256x192.py \
#     mmpose/checkpoint/rtmpose-t_8xb256-420e_coco-256x192-100-97c86b4e_20241204.pth \
#     'data/multi-person.jpg' \
#     --work-dir mmdeploy/mmdeploy_models/mmpose/ort_test \
#     --device cuda \
#     --show 



# !python mmdeploy/tools/deploy.py \
#     mmdeploy/configs/mmpose/pose-detection_onnxruntime_static.py \
#     mmpose/work_dirs/rtmpose-t_8xb256-420e_coco-256x192/rtmpose-t_8xb256-420e_coco-256x192.py \
#     mmpose/checkpoint/rtmpose-t_8xb256-420e_coco-256x192-100-97c86b4e_20241204.pth \
#     'data/test/multi-person.jpg' \
#     --work-dir mmdeploy/mmdeploy_models/mmpose/ort_test \
#     --device cuda \
#     --show
# Out:
# Arguments: Namespace(calib_dataset_cfg=None, checkpoint='mmpose/checkpoint/rtmpose-t_8xb256-420e_coco-256x192-100-97c86b4e_20241204.pth', deploy_cfg='mmdeploy/configs/mmpose/pose-detection_simcc_onnxruntime_dynamic.py', device='cuda', dump_info=True, img='mmpose/data/test/human-pose.jpg', log_level='INFO', model_cfg='mmpose/configs/body_2d_keypoint/rtmpose/coco/rtmpose-t_8xb256-420e_coco-256x192.py', quant=True, quant_image_dir=None, show=True, test_img=None, uri='192.168.1.1:60000', work_dir='mmdeploy/mmdeploy_models/mmpose/ort_test_ding')
# 12/05 13:35:36 - mmengine - WARNING - Failed to search registry with scope "mmpose" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmpose" is a correct scope, or whether the registry is initialized.
# ...

# %%
# multi person

# !python mmdeploy/tools/deploy.py \
    mmdeploy/configs/mmpose/pose-detection_onnxruntime_static.py \
    mmpose/configs/wholebody_2d_keypoint/topdown_heatmap/coco-wholebody/td-hm_hrnet-w48_dark-8xb32-210e_coco-wholebody-384x288.py \
    mmpose/checkpoint/wholebody_2d_keypoint/hrnet_w48_coco_wholebody_384x288_dark-f5726563_20200918.pth \
    'data/multi-person.jpg' \
    --work-dir mmdeploy/mmdeploy_models/mmpose/ort_test_multi \
    --device cuda \
    --show \
    --dump-info \
    --quant
# Out:
# Arguments: Namespace(calib_dataset_cfg=None, checkpoint='mmpose/checkpoint/wholebody_2d_keypoint/hrnet_w48_coco_wholebody_384x288_dark-f5726563_20200918.pth', deploy_cfg='mmdeploy/configs/mmpose/pose-detection_onnxruntime_static.py', device='cuda', dump_info=True, img='mmpose/data/test/multi-person.jpg', log_level='INFO', model_cfg='mmpose/configs/wholebody_2d_keypoint/topdown_heatmap/coco-wholebody/td-hm_hrnet-w48_dark-8xb32-210e_coco-wholebody-384x288.py', quant=True, quant_image_dir=None, show=True, test_img=None, uri='192.168.1.1:60000', work_dir='mmdeploy/mmdeploy_models/mmpose/ort_test_multi')
# 12/05 14:02:16 - mmengine - WARNING - Failed to search registry with scope "mmpose" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmpose" is a correct scope, or whether the registry is initialized.
# ...

# %%
# !python mmdeploy/tools/deploy.py \
    mmdeploy/configs/mmpose/pose-detection_simcc_onnxruntime_dynamic.py \
    mmpose/projects/rtmpose/rtmpose/wholebody_2d_keypoint/rtmpose-l_8xb64-270e_coco-wholebody-256x192.py \
    mmpose/checkpoint/rtmpose-l_simcc-coco-wholebody_pt-aic-coco_270e-256x192-6f206314_20230124.pth \
    'data/human-pose.jpg' \
    --work-dir mmdeploy/mmdeploy_models/mmpose/ort_test \
    --device cuda \
    --show \
    --dump-info \
    --quant
# Out:
# Arguments: Namespace(calib_dataset_cfg=None, checkpoint='mmpose/checkpoint/rtmpose-l_simcc-coco-wholebody_pt-aic-coco_270e-256x192-6f206314_20230124.pth', deploy_cfg='mmdeploy/configs/mmpose/pose-detection_simcc_onnxruntime_dynamic.py', device='cuda', dump_info=True, img='mmpose/data/test/human-pose.jpg', log_level='INFO', model_cfg='mmpose/projects/rtmpose/rtmpose/wholebody_2d_keypoint/rtmpose-l_8xb64-270e_coco-wholebody-256x192.py', quant=True, quant_image_dir=None, show=True, test_img=None, uri='192.168.1.1:60000', work_dir='mmdeploy/mmdeploy_models/mmpose/ort_test')
# 12/05 13:32:52 - mmengine - WARNING - Failed to search registry with scope "mmpose" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmpose" is a correct scope, or whether the registry is initialized.
# ...

# %%
# !python mmdeploy/tools/deploy.py \
    mmdeploy/configs/mmpose/pose-detection_simcc_onnxruntime_dynamic.py \
    mmpose/configs/body_2d_keypoint/rtmpose/coco/rtmpose-t_8xb256-420e_coco-256x192.py \
    mmpose/checkpoint/td-hm_hrnet-w48_8xb32-210e_coco-256x192-0e67c616_20220913.pth \
    'data/multi-person.jpg' \
    --work-dir mmdeploy/mmdeploy_models/mmpose/ort_test \
    --device cuda \
    --show \
    --dump-info \
    --quant
# Out:
# Arguments: Namespace(calib_dataset_cfg=None, checkpoint='mmpose/checkpoint/td-hm_hrnet-w48_8xb32-210e_coco-256x192-0e67c616_20220913.pth', deploy_cfg='mmdeploy/configs/mmpose/pose-detection_simcc_onnxruntime_dynamic.py', device='cuda', dump_info=True, img='mmpose/data/test/multi-person.jpg', log_level='INFO', model_cfg='mmpose/configs/body_2d_keypoint/rtmpose/coco/rtmpose-t_8xb256-420e_coco-256x192.py', quant=True, quant_image_dir=None, show=True, test_img=None, uri='192.168.1.1:60000', work_dir='mmdeploy/mmdeploy_models/mmpose/ort_test')
# 12/05 10:52:56 - mmengine - WARNING - Failed to search registry with scope "mmpose" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmpose" is a correct scope, or whether the registry is initialized.
# ...

# %% [markdown]
# ## 生成以下文件
#
# 验证转换成功（非必需）：
#
# - output_onnxruntime.jpg：用ONNX Runtime推理框架的预测结果，应与`output_pytorch.jpg`几乎相同
#
# - output_pytorch.jpg：用原生Pytorch的预测结果，应与`output_onnxruntime.jpg`几乎相同
#
# - detail.json：模型转ONNX的信息，用于追溯bug
#
# 转换得到的模型及信息（必需）：
#
# - deploy.json：模型描述，用于MMDeploy Runtime推理
#
# - end2end.onnx：ONNX模型
#
# - pipeline.json：模型输入、推理、后处理，每一步骤的输入输出信息
