# %% [markdown]
# # 关键点检测-训练RTMPose

# %% [markdown]
# ## 训练（建议在命令行中运行）

# %%
# !python mmpose/tools/train.py mmpose/configs/body_2d_keypoint/rtmpose/coco/rtmpose-t_8xb256-420e_coco-256x192.py
# Out:
# /home/dshengq/anaconda3/envs/openmmlab_pose1.3/lib/python3.8/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 12/03 21:17:55 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.20 (default, Oct  3 2024, 15:24:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 21
#     GPU 0: NVIDIA GeForce RTX 3080
#     CUDA_HOME: /usr/local/cuda-11.8/
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %% [markdown]
# ## 测试集上评估模型精度

# %%
# !python mmpose/tools/test.py mmpose/configs/body_2d_keypoint/rtmpose/coco/rtmpose-t_8xb256-420e_coco-256x192.py \
                      mmpose/work_dirs/rtmpose-t_8xb256-420e_coco-256x192/epoch_420.pth
